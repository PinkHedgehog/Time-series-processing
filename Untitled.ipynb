# %%
# %load_ext autoreload
# %autoreload 2

# %%
# подгрузка необходимых модулей
import numpy as np # работа с числами, массивами и проч.
import pandas as pd # загрузка/выгрузка табличных данных (датафреймов)
import matplotlib.pyplot as plt # визуализация результатов
from statsmodels.tsa.statespace.sarimax import SARIMAX # статмодель для анализа временных рядов
from tbats import TBATS # статмодель для анализа временных рядов

# %% [markdown]
# Keywords: ARIMA, AutoRegressive Integrated Moving Average
#
# https://builtin.com/data-science/time-series-forecasting-python
#
# https://towardsdatascience.com/machine-learning-part-19-time-series-and-autoregressive-integrated-moving-average-model-arima-c1005347b0d7
#
# https://www.kaggle.com/tsarkov90/crime-in-russia-20032020?select=crime.csv
#
# https://github.com/Lotaristo/Projects/blob/main/Russan%20Crimes%20Dashboard
#
# https://www.influxdata.com/time-series-forecasting-methods/
#
# https://towardsdatascience.com/temporal-loops-intro-to-recurrent-neural-networks-for-time-series-forecasting-in-python-b0398963dc1f
#
# https://medium.com/analytics-vidhya/time-series-forecasting-using-tbats-model-ce8c429442a9

# %%
# загрузка датафрейма
crime_df = pd.read_csv('crime.csv', parse_dates=['month'], index_col=['month'], dayfirst=True)
crime_df.describe()
# Out:
#         Total_crimes        Serious   Huge_damage   Ecological    Terrorism  \
# count     205.000000     205.000000    205.000000   205.000000   205.000000
# mean   221279.019512   59068.487805  38402.039024  2592.463415   197.839024
# std     51720.759692   20501.515982  20755.286960  1028.101551   245.462645
# min    137657.000000   15755.000000   7424.000000  1216.000000    12.000000
# 25%    180711.000000   42135.000000  21813.000000  1888.000000    57.000000
# 50%    207550.000000   51426.000000  26357.000000  2322.000000   103.000000
# 75%    254352.000000   78407.000000  59282.000000  3034.000000   184.000000
# max    359098.000000  108299.000000  87941.000000  6822.000000  1198.000000
#
#         Extremism       Murder  Harm_to_health         Rape          Theft  \
# count  205.000000   205.000000      205.000000   205.000000     205.000000
# mean    59.473171  1451.400000     3276.024390   463.580488   92647.560976
# std     42.070500   687.713793     1013.861819   188.413369   25376.346430
# min      2.000000   534.000000     1467.000000   134.000000   50155.000000
# 25%     26.000000   932.000000     2479.000000   322.000000   72533.000000
# 50%     52.000000  1200.000000     3256.000000   419.000000   88095.000000
# 75%     87.000000  1975.000000     4152.000000   574.000000  107555.000000
# max    174.000000  3099.000000     5578.000000  1027.000000  153394.000000
#
#        Vehicle_theft    Fraud_scam      Hooligan         Drugs      Weapons
# count     205.000000    205.000000    205.000000    205.000000   205.000000
# mean     4101.414634  15277.834146   1457.648780  17644.356098  2525.019512
# std      1565.682727   4114.474680   2560.889194   3068.123707   733.169890
# min      1092.000000   5687.000000    132.000000   7275.000000  1637.000000
# 25%      2928.000000  12481.000000    261.000000  16006.000000  2029.000000
# 50%      3923.000000  15303.000000    486.000000  17924.000000  2351.000000
# 75%      5125.000000  18005.000000   1785.000000  19686.000000  2868.000000
# max      8251.000000  27980.000000  12636.000000  25187.000000  5938.000000

# %%
# Отрисуем распределение терроризма и экстремизма
plt.plot(crime_df.index, crime_df['Terrorism'], label='Terrorism')
plt.plot(crime_df.index, crime_df['Extremism'], label='Extremism')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
description_of_crimes = crime_df.describe()

# %%
# разобьём выборку на обучающую и тестовую
train = crime_df[crime_df.index < pd.to_datetime("2016-11-01", format='%Y-%m-%d')]
test = crime_df[crime_df.index > pd.to_datetime("2016-11-01", format='%Y-%m-%d')]
plt.plot(train['Extremism'], color = "black")
plt.plot(test['Extremism'], color = "red")
plt.ylabel('# of cirmes')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title(f"Train/Test split for {'Extremism'}")
plt.show()

# %%
# вспомогательная функция для визуализации графиков
def visualize(crime_types, train_df, test_df):
    """PLot images in one row."""
    n = len(crime_types)
    plt.figure(figsize=(32, 24))
    
    for i, ct in enumerate(crime_types):
        plt.subplot(n % 5 + 1, n // 5 + 1, i + 1)
        #plt.ylabel('# of cirmes')
        #plt.xlabel('Date')
        plt.xticks(rotation=45)

        plt.title(ct)
        plt.plot(train_df[ct], color = "blue")
        plt.plot(test_df[ct], color = "orange")
    plt.show()

# %%
visualize(crime_types_sorted_by_mean[:-1], train, test)

# %%
#y = crime_df['Extremism']
y = train

# %%
# запуск модели на основе скользящего окна для экстремизма
ARMAmodel = SARIMAX(train['Extremism'], order = (1, 0, 1))
ARMAmodel = ARMAmodel.fit()
# Out:
# /home/andrey/Documents/Progs/Python/Time-series-processing/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /home/andrey/Documents/Progs/Python/Time-series-processing/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.38544D+00    |proj g|=  8.34561D-02
#
# At iterate    5    f=  4.36930D+00    |proj g|=  3.27557D-03
#
# At iterate   10    f=  4.36874D+00    |proj g|=  7.84702D-04
#
# At iterate   15    f=  4.36831D+00    |proj g|=  3.47854D-03
#
# At iterate   20    f=  4.36817D+00    |proj g|=  5.53957D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     20     21      1     0     0   5.540D-06   4.368D+00
#   F =   4.3681736154413144
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.

# %%
# получаем предсказание
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05)
print(type(y_pred_df))
y_pred_df["Predictions"] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# визуализируем результат
plt.plot(y_pred_out, color='green', label = 'SARIMA')
plt.plot(test['Extremism'], color='orange', label='Test - Extremism')
plt.xticks(rotation=45)
plt.legend()

# %%
# запускаем модель на основе TBATS для предсказания экстремизма
estimator = TBATS()
fitted_model = estimator.fit(train['Extremism'])
y_forecasted = fitted_model.forecast(steps=len(test))
y_tbats = pd.DataFrame(y_forecasted, index=test.index)
# print(fitted_model.summary())
    
# # Time series analysis
# print(fitted_model.y_hat) # in sample prediction
# print(fitted_model.resid) # in sample residuals
# print(fitted_model.aic)
# # Reading model parameters
# print(fitted_model.params.alpha)
# print(fitted_model.params.beta)
# print(fitted_model.params.x0)
# print(fitted_model.params.components.use_box_cox)

# %%
plt.plot(y_pred_out, color='green', label = 'SARIMA')
plt.plot(test['Extremism'], color='orange', label='Test')
plt.plot(y_tbats, color='blue', label = 'TBATS')
plt.xticks(rotation=45)
plt.title('Extremism')
plt.legend()

# %%
ARMAmodel = SARIMAX(train['Total_crimes'], order = (1, 0, 1))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05)
print(type(y_pred_df))
y_pred_df["Predictions"] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out_total = y_pred_df["Predictions"]
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.12274D+01    |proj g|=  3.18224D-02
#
# At iterate    5    f=  1.12264D+01    |proj g|=  3.42826D-03
#
# At iterate   10    f=  1.12250D+01    |proj g|=  1.32776D-02
#
# At iterate   15    f=  1.12246D+01    |proj g|=  1.41938D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     18      1     0     0   1.419D-05   1.122D+01
#   F =   11.224620492622606
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# <class 'pandas.core.frame.DataFrame'>
# /home/andrey/Documents/Progs/Python/Time-series-processing/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /home/andrey/Documents/Progs/Python/Time-series-processing/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
estimator2 = TBATS()
fitted_model2 = estimator2.fit(train['Total_crimes'])
y_forecasted2 = fitted_model2.forecast(steps=len(test))
y_tbats_total = pd.DataFrame(y_forecasted2, index=test.index)

# %%
plt.plot(y_pred_out_total, color='green', label = 'SARIMA')
plt.plot(test['Total_crimes'], color='orange', label='Test')
plt.plot(y_tbats_total, color='blue', label = 'TBATS')
plt.xticks(rotation=45)
plt.title('Total crimes')
plt.legend()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd


import torch.optim as optim
#from torch.utils.tensorboard import SummaryWriter

from darts.dataprocessing.transformers import Scaler
from darts.models import RNNModel, Theta
from darts.metrics import mape, rmse, r2_score
from darts.utils.statistics import check_seasonality, plot_acf, plot_pacf
from darts.utils.timeseries_generation import datetime_attribute_timeseries

from darts.datasets import SunspotsDataset, AirPassengersDataset

import sys
import time
import warnings
warnings.filterwarnings("ignore")
import logging
logging.disable(logging.CRITICAL)


FC_N = 36               # forecast periods
FC_STRIDE = 10
FC_START = "19590101"   # period at which to split training and validation dataset

EPOCH = 300       # for testing or debugging, rather than real forecasts, 
                  # set EPOCH to a low value like 3; for the real deal: 300 
                  # 300 will take as much as 30 - 50 minutes of processing time
## load data
ts = AirPassengersDataset().load()

series = ts  
df = ts.pd_dataframe()
df
# Out:
# component   #Passengers
# Month
# 1949-01-01        112.0
# 1949-02-01        118.0
# 1949-03-01        132.0
# 1949-04-01        129.0
# 1949-05-01        121.0
# ...                 ...
# 1960-08-01        606.0
# 1960-09-01        508.0
# 1960-10-01        461.0
# 1960-11-01        390.0
# 1960-12-01        432.0
#
# [144 rows x 1 columns]

# %%
plt.figure(100, figsize=(12, 5))
series.plot()

# %%
# analyze its seasonality

is_seasonal, periodicity = check_seasonality(ts, max_lag=240)
dict_seas ={
    "is seasonal?":is_seasonal, 
    "periodicity (months)":f'{periodicity:.1f}', 
    "periodicity (~years)": f'{periodicity/12:.1f}'}
dict_seas
#_ = [print(k,":",v) for k,v in dict_seas.items()]
# Out:
# {'is seasonal?': True,
#  'periodicity (months)': '12.0',
#  'periodicity (~years)': '1.0'}

# %%
# split training vs test dataset
train, val = ts.split_after(pd.Timestamp(FC_START))

# %%
# normalize the time series

trf = Scaler()
# fit the transformer to the training dataset
train_trf = trf.fit_transform(train)
# apply the transformer to the validation set and the complete series 
val_trf = trf.transform(val)
ts_trf = trf.transform(ts)

# %%
# create month and year covariate series

year_series = datetime_attribute_timeseries(
    pd.date_range(start=series.start_time(), 
        freq=ts.freq_str, 
        periods=1000),
    attribute='year', 
    one_hot=False)
year_series = Scaler().fit_transform(year_series)

month_series = datetime_attribute_timeseries(
    year_series, 
    attribute='month', 
    one_hot=True)

covariates = year_series.stack(month_series)
cov_train, cov_val = covariates.split_after(pd.Timestamp(FC_START))

# %%
# set up, fit, run, plot, and evaluate the RNN model

def run_RNN(flavor, ts, train, val):

    # set the model up
    model_RNN = RNNModel(
        model=flavor,
        model_name=flavor + str(" RNN"),
        input_chunk_length=periodicity,
        training_length=20,
        hidden_dim=20,
        batch_size=16,
        n_epochs=EPOCH,
        dropout=0,
        optimizer_kwargs={'lr': 1e-3},
        log_tensorboard=True,
        random_state=42,
        force_reset=True,
        torch_device_str='cuda:0'
    )
        
    if flavor == "RNN": flavor = "Vanilla" 

    # fit the model
    fit_it(model_RNN, train, val, flavor)

    # compute N predictions
    pred = model_RNN.predict(n=FC_N, future_covariates=covariates) 

    # plot predictions vs actual
    plot_fitted(pred, ts, flavor)

    # print accuracy metrics
    res_acc = accuracy_metrics(pred, ts)    
    print(flavor + " : ")
    _ = [print(k,":",f'{v:.4f}') for k,v in res_acc.items()]

    return [pred, res_acc]

# %%
# helper function: compute accuracy metrics
   
def accuracy_metrics(pred, act):
    act2 = act.slice_intersect(pred)
    pred2 = pred.slice_intersect(act2)
    resid = pred2 - act2
    sr = resid.pd_series()
    sa = act2.pd_series()
    sp = pred2.pd_series()
    res_mape = mape(pred2, act2)
    res_r2 = r2_score(pred2, act2)
    res_rmse = rmse(pred2, act2)
    res_pe = sr / sa
    n_act = len(act2)
    res_rmspe = np.sqrt(np.sum(res_pe**2) / n_act)    # root mean square percentage error
    res_std = np.std(sr)                               # std error of the model = std deviation of the noise
    res_se = res_std / np.sqrt(n_act)                  # std error in estimating the mean
    res_sefc = np.sqrt(res_std + res_se**2)            # std error of the forecast
    
    res_accuracy = {
        "MAPE":res_mape,"RMSPE":res_rmspe, "RMSE":res_rmse, 
        "-R squared":-res_r2, "se": res_sefc}
    return res_accuracy

# %%
# helper function: fit the RNN model

def fit_it(model, train, val, flavor):
    t_start =  time.perf_counter()
    print("\nbeginning the training of the {0} RNN:".format(flavor))

    res = model.fit(train,
             future_covariates=covariates,
             val_series=val,
             val_future_covariates=covariates,
             verbose=True)

    res_time = time.perf_counter() - t_start
    print("training of the {0} RNN has completed:".format(flavor), f'{res_time:.2f} sec')

    return res

# %%
# helper function: plot the predictions

def plot_fitted(pred, act, flavor):
    plt.figure(figsize=(12,5))
    act.plot(label='actual')
    pred.plot(label='prediction')
    plt.title("RNN: {0} flavor".format(flavor) + ' | MAPE: {:.2f}%'.format(mape(pred, act)))
    plt.legend();

# %%
# run 3 different flavors of RNN on the time series:
flavors = ["LSTM", "GRU", "RNN"]

# call the RNN model setup for each of the 3 RNN flavors
res_flavors = [run_RNN(flv, ts_trf, train_trf, val_trf) for flv in flavors]
# Out:
# beginning the training of the LSTM RNN:
# Epoch 0:  88%|███████████████████████████████████████████████████████████████         | 7/8 [00:00<00:00, 38.46it/s, loss=0.085, v_num=logs, train_loss=0.0352]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 38.72it/s, loss=0.085, v_num=logs, train_loss=0.0352, val_loss=0.545]
# Epoch 1:  88%|████████████████████████████████████████████████▏      | 7/8 [00:00<00:00, 18.56it/s, loss=0.0761, v_num=logs, train_loss=0.0348, val_loss=0.545]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|███████████████████████████████████████████████████████| 8/8 [00:00<00:00, 19.97it/s, loss=0.0761, v_num=logs, train_loss=0.0348, val_loss=0.460]
# Epoch 2:  88%|████████████████████████████████████████████████▏      | 7/8 [00:00<00:00, 12.18it/s, loss=0.0671, v_num=logs, train_loss=0.0335, val_loss=0.460]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|███████████████████████████████████████████████████████| 8/8 [00:00<00:00, 13.38it/s, loss=0.0671, v_num=logs, train_loss=0.0335, val_loss=0.379]
# Epoch 3:  88%|████████████████████████████████████████████████▏      | 7/8 [00:00<00:00,  9.19it/s, loss=0.0518, v_num=logs, train_loss=0.0317, val_loss=0.379]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|███████████████████████████████████████████████████████| 8/8 [00:00<00:00, 10.04it/s, loss=0.0518, v_num=logs, train_loss=0.0317, val_loss=0.309]
# Epoch 4:  88%|████████████████████████████████████████████████▏      | 7/8 [00:00<00:00,  7.24it/s, loss=0.0444, v_num=logs, train_loss=0.0509, val_loss=0.309]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|███████████████████████████████████████████████████████| 8/8 [00:00<00:00,  8.03it/s, loss=0.0444, v_num=logs, train_loss=0.0509, val_loss=0.263]
# Epoch 5:  88%|████████████████████████████████████████████████▏      | 7/8 [00:01<00:00,  5.86it/s, loss=0.0406, v_num=logs, train_loss=0.0332, val_loss=0.263]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|███████████████████████████████████████████████████████| 8/8 [00:01<00:00,  6.53it/s, loss=0.0406, v_num=logs, train_loss=0.0332, val_loss=0.247]
# Epoch 6:  88%|████████████████████████████████████████████████▏      | 7/8 [00:01<00:00,  5.01it/s, loss=0.0386, v_num=logs, train_loss=0.0484, val_loss=0.247]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|███████████████████████████████████████████████████████| 8/8 [00:01<00:00,  5.61it/s, loss=0.0386, v_num=logs, train_loss=0.0484, val_loss=0.240]
# Epoch 7:  88%|████████████████████████████████████████████████▏      | 7/8 [00:01<00:00,  4.43it/s, loss=0.0365, v_num=logs, train_loss=0.0178, val_loss=0.240]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|███████████████████████████████████████████████████████| 8/8 [00:01<00:00,  5.00it/s, loss=0.0365, v_num=logs, train_loss=0.0178, val_loss=0.235]
# Epoch 8:  88%|█████████████████████████████████████████████████       | 7/8 [00:01<00:00,  4.05it/s, loss=0.0348, v_num=logs, train_loss=0.032, val_loss=0.235]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch

# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 295: 100%|███████████████████████████████████████████████| 8/8 [00:27<00:00,  3.48s/it, loss=0.000349, v_num=logs, train_loss=0.000225, val_loss=0.00238]
# Epoch 296:  88%|█████████████████████████████████████████▏     | 7/8 [00:27<00:03,  3.99s/it, loss=0.000346, v_num=logs, train_loss=0.000332, val_loss=0.00238]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 296: 100%|████████████████████████████████████████████████| 8/8 [00:27<00:00,  3.49s/it, loss=0.000346, v_num=logs, train_loss=0.000332, val_loss=0.0024]
# Epoch 297:  88%|██████████████████████████████████████████      | 7/8 [00:28<00:04,  4.00s/it, loss=0.000344, v_num=logs, train_loss=0.000223, val_loss=0.0024]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 297: 100%|███████████████████████████████████████████████| 8/8 [00:28<00:00,  3.51s/it, loss=0.000344, v_num=logs, train_loss=0.000223, val_loss=0.00238]
# Epoch 298:  88%|██████████████████████████████████████████      | 7/8 [00:28<00:04,  4.02s/it, loss=0.00035, v_num=logs, train_loss=0.000245, val_loss=0.00238]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 298: 100%|████████████████████████████████████████████████| 8/8 [00:28<00:00,  3.52s/it, loss=0.00035, v_num=logs, train_loss=0.000245, val_loss=0.00237]
# Epoch 299:  88%|█████████████████████████████████████████▏     | 7/8 [00:28<00:04,  4.03s/it, loss=0.000344, v_num=logs, train_loss=0.000327, val_loss=0.00237]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                           | 0/1 [00:00<?, ?it/s]
# Epoch 299: 100%|███████████████████████████████████████████████| 8/8 [00:28<00:00,  3.53s/it, loss=0.000344, v_num=logs, train_loss=0.000327, val_loss=0.00237]
# Epoch 299: 100%|███████████████████████████████████████████████| 8/8 [00:28<00:00,  3.53s/it, loss=0.000344, v_num=logs, train_loss=0.000327, val_loss=0.00237]
# training of the Vanilla RNN has completed: 28.25 sec
# Predicting DataLoader 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, -451.79it/s]
# Vanilla :
# MAPE : 3.3941
# RMSPE : 0.0401
# RMSE : 0.0410
# -R squared : -0.9354
# se : 0.1860

# %%
# Theta forecaster

# search space for best theta value: check 100 alternatives
thetas = 2 - np.linspace(-10, 10, 100)

# initialize search
best_mape = float('inf')
best_theta = 0
t_start =  time.perf_counter()
# search for best theta among 100 values, as measured by MAPE
for theta in thetas:
    model = Theta(theta)
    res = model.fit(train)
    pred_theta = model.predict(len(val))
    res_mape = mape(val, pred_theta)
    if res_mape < best_mape:
        best_mape = res_mape
        best_theta = theta


# fit the model
best_theta_model = Theta(best_theta)
best_theta_model.fit(train)
pred = best_theta_model.predict(len(val))

# review the Theta results
plt.figure(figsize=(12,5))
train.plot(label='actual: training set')
val.plot(label='actual: validation set')
pred.plot(label='Theta predictions')
plt.title("Theta: {0}".format(best_theta) + ' | MAPE: {:.2f}%'.format(mape(pred, val)))
plt.legend();

res_time = time.perf_counter() - t_start
res_acc = accuracy_metrics(pred, val)
print("Theta forecast has completed: ", f'{res_time:.2f} sec')
_ = [print(k,":",f'{v:.4f}') for k,v in res_acc.items()]
results = [pred, res_acc]
#view rawrnn_25_theta1 hosted with ❤ by GitHub
# Out:
# Theta forecast has completed:  2.03 sec
# MAPE : 3.1119
# RMSPE : 0.0448
# RMSE : 20.4686
# -R squared : -0.8987
# se : 6.2176

# %%
# collect the forecasters's accuracy metrics in a dataframe

dict_models = {"LSTM":res_flavors[0][1], "GRU":res_flavors[1][1],
    "Vanilla":res_flavors[2][1], "Theta":res_acc}
df_acc = pd.DataFrame.from_dict(dict_models, orient="index").T
pd.set_option("display.precision",3)
df_acc.style.highlight_min(color="lightgreen", axis=1).highlight_max(color="blue", axis=1)
# Out:
# <style type="text/css">
# #T_096e7_row0_col0, #T_096e7_row1_col0, #T_096e7_row2_col3, #T_096e7_row3_col3, #T_096e7_row4_col3 {
#   background-color: blue;
# }
# #T_096e7_row0_col3, #T_096e7_row1_col2, #T_096e7_row2_col2, #T_096e7_row3_col2, #T_096e7_row4_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_096e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_096e7_level0_col0" class="col_heading level0 col0" >LSTM</th>
#       <th id="T_096e7_level0_col1" class="col_heading level0 col1" >GRU</th>
#       <th id="T_096e7_level0_col2" class="col_heading level0 col2" >Vanilla</th>
#       <th id="T_096e7_level0_col3" class="col_heading level0 col3" >Theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_096e7_level0_row0" class="row_heading level0 row0" >MAPE</th>
#       <td id="T_096e7_row0_col0" class="data row0 col0" >5.031626</td>
#       <td id="T_096e7_row0_col1" class="data row0 col1" >4.811109</td>
#       <td id="T_096e7_row0_col2" class="data row0 col2" >3.394094</td>
#       <td id="T_096e7_row0_col3" class="data row0 col3" >3.111937</td>
#     </tr>
#     <tr>
#       <th id="T_096e7_level0_row1" class="row_heading level0 row1" >RMSPE</th>
#       <td id="T_096e7_row1_col0" class="data row1 col0" >0.052943</td>
#       <td id="T_096e7_row1_col1" class="data row1 col1" >0.051441</td>
#       <td id="T_096e7_row1_col2" class="data row1 col2" >0.040064</td>
#       <td id="T_096e7_row1_col3" class="data row1 col3" >0.044793</td>
#     </tr>
#     <tr>
#       <th id="T_096e7_level0_row2" class="row_heading level0 row2" >RMSE</th>
#       <td id="T_096e7_row2_col0" class="data row2 col0" >0.047609</td>
#       <td id="T_096e7_row2_col1" class="data row2 col1" >0.048651</td>
#       <td id="T_096e7_row2_col2" class="data row2 col2" >0.041005</td>
#       <td id="T_096e7_row2_col3" class="data row2 col3" >20.468560</td>
#     </tr>
#     <tr>
#       <th id="T_096e7_level0_row3" class="row_heading level0 row3" >-R squared</th>
#       <td id="T_096e7_row3_col0" class="data row3 col0" >-0.927116</td>
#       <td id="T_096e7_row3_col1" class="data row3 col1" >-0.918127</td>
#       <td id="T_096e7_row3_col2" class="data row3 col2" >-0.935392</td>
#       <td id="T_096e7_row3_col3" class="data row3 col3" >-0.898710</td>
#     </tr>
#     <tr>
#       <th id="T_096e7_level0_row4" class="row_heading level0 row4" >se</th>
#       <td id="T_096e7_row4_col0" class="data row4 col0" >0.169070</td>
#       <td id="T_096e7_row4_col1" class="data row4 col1" >0.178939</td>
#       <td id="T_096e7_row4_col2" class="data row4 col2" >0.185979</td>
#       <td id="T_096e7_row4_col3" class="data row4 col3" >6.217629</td>
#     </tr>
#   </tbody>
# </table>
